# %%
from ultralytics import YOLO

model = YOLO('models/best.pt')

results = model.predict('input_videos/test (11).mp4', save = True)
print(results[0])
print('==============================')
for box in results[0].boxes:
    print(box)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /Users/ericchoi/Downloads/AI:ML Football Analysis/input_videos/test (11).mp4: 384x640 19 players, 3 referees, 289.6ms
# video 1/1 (frame 2/750) /Users/ericchoi/Downloads/AI:ML Football Analysis/input_videos/test (11).mp4: 384x640 1 ball, 17 players, 3 referees, 270.9ms
# video 1/1 (frame 3/750) /Users/ericchoi/Downloads/AI:ML Football Analysis/input_videos/test (11).mp4: 384x640 17 players, 3 referees, 263.4ms
# ...
